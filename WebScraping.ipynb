# %% [markdown]
# Web Scraping using beautifulsoup

# %%
from bs4 import BeautifulSoup

# %%
def get_page():
  page=requests.get("https://www.rjcollege.edu.in/")
  soup=BeautifulSoup(page.content, 'html.parser')
  print(soup.find_all('p')[0].get_text())
  print(soup.find_all('p')[1].get_text())
  print(soup.find_all('p')[2].get_text())

# %%
if __name__ =="__main__":
  get_page()
# Out:
# FIRST MERIT LIST of 11th/FYJC Academic Year 2022-23 (Only for Linguistic Minority -Hindi and In-house (Hindi High School, Ghatkopar) LiNK
# First Year Junior College Admission 2022-23   LiNK:11th/FYJC Online Admission 2022-23
